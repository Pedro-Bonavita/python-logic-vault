# %%
# importando as bibliotecas
# pip install nome_da_biblioteca

import numpy as np
#numpy é uma biblioteca de funções matemáticas
# np é o apelido

# %%
# sem usar o numpy
# matemática básica
numero1 = float(input('informe o primeiro número'))
numero2 = floar(input('informe o segundo número'))

#soma
soma = numero1 + numero2
print(soma)
#subtração
subtracao = numero1 - numero2
print(subtracao)
#divisão
divi = numero1/numero2
print(divi)
#multiplicação
multi = numero1*numero2
print(multi)

# %%
# usando numpy
# matematica basica
numero1 = float(input('informe o primeiro número'))
numero2 = floar(input('informe o segundo número'))

# soma pode ser sum ou add
print(f'soma: {np.add(numero1,numero2)}')
# método sum apenas para números inteiros

#subtrair
print(f'subtração:{np.subtract(numero1, numero2)}')

#multiplicar
print(f'multiplicação:{np.multiply(numero1,numero2)}')

# %%
lista_nome = []
lista_valor = []
lista_quantidade = []

while True:

  op_tem = input('Deseja passar algum produto no caixa? S/N')

  if op_tem.lower() == 'n':
    print('sistema finalizado')
    break
  elif op_tem.lower() =='s':
    while True:
      # criar variaveis e listas
      nome = input('Qual o produto?')
      valor = float(input('informe o valor'))
      quantidade = float(input('Qual a quantidade?'))
      lista_nome.append(nome)
      lista_valor.append(valor)
      lista_quantidade.append(quantidade)

      op_novo_produto = input('tem outro produto? S/N')

      if op_novo_produto.lower() == 'n':
        print('finalizando a compra, emitindo nota fiscal')
        print('----CUPOM FISCAL----')
        print('Produto | Valor | Quantidade | Total')
        # i = produto, j = valor, k = quantidade
        # o total é a multiplicação valor x quantidade
        #transformar a lista em numpy
        np_valor = np.array(lista_valor)
        np_quantidade = np.array(lista_quantidade)
        # np.array()  - transforma um conjunto de números para numpy
        total = np.multiply(np_valor,np_quantidade)
        for i,j,k,l in zip(lista_nome, lista_valor, lista_quantidade, total):
          print(i,j,k,l)

          break
      else:
          print('Informe o novo produto')
