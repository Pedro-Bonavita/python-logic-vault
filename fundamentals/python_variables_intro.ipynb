# %%
# importando as bibliotecas do sistema
# bibliotecas importadas aqui!

# %%
# variaveis globais do sistema
alunos = ["Rafael", "Jessica", "Erick", "Taynara", "Rafael P"
]

# exibir os dados da lista
print(alunos)
# exibir um item da lista - chama a lista e seu index list[index]
print(alunos[-1])

# Index são posições dos elementos da lista
# começando em 0 até infinito. Pode-se usar o valor -1, -2, -3 e "a leitura
# será de trás para frente"
# Out:
# ['Rafael', 'Jessica', 'Erick', 'Taynara', 'Rafael P']
# Rafael P
